# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\Machine_Learning_360V2\data\processed\synthetic_sme_agents_data.csv")
df.head()
# Out:
#    sme_id business_name        revenue  profit_margin  debt_ratio  \
# 0       1         SME_1   63049.921922       0.102738    0.170476
# 1       2         SME_2   47135.917154       0.139884    0.295319
# 2       3         SME_3   68567.289121       0.094531    0.302703
# 3       4         SME_4  123677.627562       0.128443    0.370895
# 4       5         SME_5   45495.409067       0.017447    0.094971
#
#    employee_count  staff_count  age_of_business         sector  \
# 0              38           11                6       services
# 1              41            1               15         retail
# 2               7           12               19  manufacturing
# 3              78            3               21       services
# 4              53           19               15           tech
#
#    previous_funding_received  ...  education_level  employment_status  \
# 0                          0  ...         bachelor           employed
# ...

# %%
df.columns
# Out:
# Index(['sme_id', 'business_name', 'revenue', 'profit_margin', 'debt_ratio',
#        'employee_count', 'staff_count', 'age_of_business', 'sector',
#        'previous_funding_received', 'loan_applications_count',
#        'funding_requested_amount', 'project_duration_months', 'business_stage',
#        'collateral_offered', 'tax_registered', 'tax_paid_last_year',
#        'licenses_required', 'licenses_up_to_date', 'bank_balance',
#        'm_pesa_balance', 'pending_invoices', 'paid_invoices', 'campaign_spend',
#        'clicks', 'impressions', 'conversions', 'total_customers',
#        'active_customers', 'repeat_customers', 'owner_age', 'owner_gender',
#        'education_level', 'employment_status', 'location',
#        'previous_funding_amount', 'default_history', 'collateral_value',
#        'total_payroll', 'eligible_for_funding', 'default_risk',
#        'business_health_score'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# sme_id  business_name  revenue        profit_margin  debt_ratio  employee_count  staff_count  age_of_business  sector         previous_funding_received  loan_applications_count  funding_requested_amount  project_duration_months  business_stage  collateral_offered  tax_registered  tax_paid_last_year  licenses_required  licenses_up_to_date  bank_balance   m_pesa_balance  pending_invoices  paid_invoices  campaign_spend  clicks  impressions  conversions  total_customers  active_customers  repeat_customers  owner_age  owner_gender  education_level  employment_status  location  previous_funding_amount  default_history  collateral_value  total_payroll  eligible_for_funding  default_risk  business_health_score
# ...

# %%
df.shape
# Out:
# (2000, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sme_id                     2000 non-null   int64
#  1   business_name              2000 non-null   object
#  2   revenue                    2000 non-null   float64
#  3   profit_margin              2000 non-null   float64
#  4   debt_ratio                 2000 non-null   float64
#  5   employee_count             2000 non-null   int64
#  6   staff_count                2000 non-null   int64
#  7   age_of_business            2000 non-null   int64
#  8   sector                     2000 non-null   object
#  9   previous_funding_received  2000 non-null   int64
#  10  loan_applications_count    2000 non-null   int64
#  11  funding_requested_amount   2000 non-null   float64
#  12  project_duration_months    2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#             sme_id         revenue  profit_margin   debt_ratio  \
# count  2000.000000     2000.000000    2000.000000  2000.000000
# mean   1000.500000    64560.036982       0.149889     0.294481
# std     577.494589    47477.643644       0.069553     0.146069
# min       1.000000    30000.000000       0.000000     0.000000
# 25%     500.750000    40247.506821       0.100361     0.196981
# 50%    1000.500000    50737.939603       0.149996     0.295469
# 75%    1500.250000    69981.600830       0.196588     0.394323
# max    2000.000000  1000000.000000       0.424837     0.766937
#
#        employee_count  staff_count  age_of_business  \
# count     2000.000000  2000.000000      2000.000000
# mean        50.575500    24.524000        12.708500
# std         28.698974    14.520153         6.824354
# min          1.000000     0.000000         1.000000
# 25%         26.000000    12.000000         7.000000
# 50%         51.000000    24.000000        13.000000
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(8)

# %%
df.isnull().sum()
# Out:
# sme_id                       0
# business_name                0
# revenue                      0
# profit_margin                0
# debt_ratio                   0
# employee_count               0
# staff_count                  0
# age_of_business              0
# sector                       0
# previous_funding_received    0
# loan_applications_count      0
# funding_requested_amount     0
# project_duration_months      0
# business_stage               0
# collateral_offered           0
# tax_registered               0
# tax_paid_last_year           0
# licenses_required            0
# licenses_up_to_date          0
# bank_balance                 0
# m_pesa_balance               0
# pending_invoices             0
# paid_invoices                0
# campaign_spend               0
# clicks                       0
# impressions                  0
# conversions                  0
# total_customers              0
# active_customers             0
# repeat_customers             0
# ...

# %%
df['default_risk'].isnull().sum()
# Out:
# np.int64(8)

# %%
df.fillna(0, inplace = True)

# %%
df['default_risk'].isnull().sum()
# Out:
# np.int64(0)
