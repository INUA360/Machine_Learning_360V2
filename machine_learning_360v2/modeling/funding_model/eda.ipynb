# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r"C:\Users\USER\Desktop\Machine_Learning_360V2\data\processed\synthetic_onboarding_features.csv")
data.head()
# Out:
#    sme_id business_name        revenue  profit_margin  debt_ratio  \
# 0       1         SME_1   63049.921922       0.102738    0.170476
# 1       2         SME_2   47135.917154       0.139884    0.295319
# 2       3         SME_3   68567.289121       0.094531    0.302703
# 3       4         SME_4  123677.627562       0.128443    0.370895
# 4       5         SME_5   45495.409067       0.017447    0.094971
#
#    collateral_value  marketing_spend  employee_count  staff_count  \
# 0        560.527308      1592.838126               5           29
# 1       1157.020852     23465.149818              10            8
# 2          0.000000     46231.140892              12           44
# 3       1310.293284     19879.593466              82           34
# 4          0.000000     31246.123489              58           17
#
#    age_of_business  ... payroll_to_revenue  marketing_conversion_rate  \
# 0               17  ...           4.832162                   0.068517
# ...

# %%
data.dtypes.value_counts()
# Out:
# float64    30
# int64      27
# object     18
# Name: count, dtype: int64

# %%
data.describe(
)
# Out:
#             sme_id         revenue  profit_margin   debt_ratio  \
# count  1960.000000     1960.000000    1960.000000  1960.000000
# mean    999.986735    64437.770512       0.152048     0.295393
# std     577.286428    47250.563570       0.067625     0.146035
# min       1.000000    30000.000000       0.000718     0.000000
# 25%     499.750000    40247.506821       0.103886     0.197268
# 50%     997.500000    50791.814833       0.151303     0.296675
# 75%    1499.250000    69863.271279       0.196952     0.395609
# max    2000.000000  1000000.000000       0.424837     0.766937
#
#        collateral_value  marketing_spend  employee_count  staff_count  \
# count       1960.000000      1960.000000     1960.000000  1960.000000
# mean        7140.849472     25396.692435       49.241327    24.834184
# std        23344.490741     14515.057675       28.618531    14.593717
# min            0.000000         7.887229        1.000000     0.000000
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.columns
# Out:
# Index(['sme_id', 'business_name', 'revenue', 'profit_margin', 'debt_ratio',
#        'collateral_value', 'marketing_spend', 'employee_count', 'staff_count',
#        'age_of_business', 'sector', 'previous_funding_received',
#        'previous_funding_amount', 'default_history', 'loan_applications_count',
#        'funding_requested_amount', 'expected_roi', 'project_duration_months',
#        'business_stage', 'collateral_offered',
#        'business_registration_uploaded', 'tax_clearance_uploaded',
#        'financial_statements_uploaded', 'tax_registered', 'tax_paid_last_year',
#        'licenses_required', 'licenses_up_to_date', 'total_payroll',
#        'cost_per_hire', 'nssf_contribution_percent',
#        'nhif_contribution_percent', 'staff_turnover_rate', 'bank_balance',
#        'm_pesa_balance', 'pending_invoices', 'paid_invoices', 'late_payments',
#        'campaign_spend', 'clicks', 'impressions', 'conversions',
# ...

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
print(data['eligible_for_funding'].value_counts())
# Out:
# eligible_for_funding
# 1    1254
# 0     706
# Name: count, dtype: int64

# %%
print(data['default_risk'].value_counts())
# Out:
# default_risk
# low       1174
# medium     732
# high        54
# Name: count, dtype: int64
